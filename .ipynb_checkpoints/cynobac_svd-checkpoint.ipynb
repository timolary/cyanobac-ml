# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
# %matplotlib inline
import sklearn

# %% [markdown]
# ### Current samples times above the threshold

# %%
ds1 = pd.read_csv('data/AllSites.csv')
threshold = np.where(ds1['NP_Cya_bio'] >= 4e8)
target = np.zeros(len(ds1['NP_Cya_bio']))
target[threshold] = 1
ds1['target'] = pd.Series(target)
ds1 = ds1.dropna(axis=0, how='any')

# %%
t = np.where(ds1['target'] == 1.0)
ds1.iloc[t]
# ds1
# Out:
#       StationID                 Station      Date    Time Stratum Depth  \
# 936           9     Otter Creek Segment  08/18/11  1235.0       E   4.6
# 3037         40          St. Albans Bay  08/06/14  1210.0       U   2.2
# 3038         40          St. Albans Bay  08/19/14  1010.0       U   2.6
# 3269         50          Missisquoi Bay  09/22/06  1100.0       U   2.2
# 3271         50          Missisquoi Bay  10/06/06  1100.0       U   2.6
# 3307         50          Missisquoi Bay  08/20/08  1050.0       U     2
# 3400         50          Missisquoi Bay  07/30/13  1020.0       U     3
# 3461         51  Missisquoi Bay Central  09/07/06  1055.0       U   2.4
# 3464         51  Missisquoi Bay Central  09/22/06  1040.0       U     2
# 3499         51  Missisquoi Bay Central  08/06/08  1115.0       U     2
# 3556         51  Missisquoi Bay Central  08/12/11  1105.0       U     3
# 3574         51  Missisquoi Bay Central  08/06/12  1050.0       U   1.8
# 3575         51  Missisquoi Bay Central  08/21/12  1245.0       U     1
# 3610         51  Missisquoi Bay Central  08/20/14  1100.0       U   1.8
# 3624         51  Missisquoi Bay Central  07/20/15  1132.0       U   2.4
# 3627         51  Missisquoi Bay Central  08/06/15  1103.0       U   2.2
# 3632         51  Missisquoi Bay Central  09/17/15  1100.0       U     2
#
#          TP    DP    Cl     TN  TempC    Chla Secchi    NP_Cya_bio  target
# 936    15.7   9.3  12.6  H0.35   22.1    10.4    2.3  4.260000e+08     1.0
# 3037     37  12.1  10.6   0.74   24.7    28.2    1.1  7.110000e+08     1.0
# 3038   41.7  13.5  10.9   0.61   20.5   25.38    1.3  7.280000e+08     1.0
# 3269   75.5  23.2   6.7   0.64   17.3      36    1.1  4.230000e+08     1.0
# 3271   69.4  33.6   7.3   0.63   13.0    12.6    1.3  7.050000e+08     1.0
# 3307   66.4  16.6   5.9   0.74   21.3    44.9      1  1.260000e+09     1.0
# 3400   40.2    16   7.7    0.8   23.8   45.03    1.5  1.170000e+09     1.0
# 3461   62.9    18   6.3   0.77   19.3    3.73    1.2  4.380000e+08     1.0
# 3464   73.7  19.5   6.6    0.8   17.3    42.4    0.8  1.540000e+09     1.0
# 3499   74.1  29.7   7.1   0.81   23.2    45.5    1.1  1.190000e+09     1.0
# 3556   61.4    20     6  H0.55   23.5   J31.8    1.5  5.190000e+08     1.0
# 3574    109  46.8   7.5   0.61   25.5  H33.27    0.9  4.150000e+08     1.0
# 3575  H88.7  20.1   7.8  H0.87   23.1  H113.1    0.5  1.670000e+09     1.0
# 3610   96.1  29.5   8.5   1.04   20.6   34.73    0.9  7.340000e+08     1.0
# 3624   48.7  22.7   8.1   0.83   24.1   21.63    1.2  4.880000e+08     1.0
# 3627   67.4  25.8   7.7   0.71   23.4   42.08    1.1  4.720000e+08     1.0
# 3632   94.2  40.7   8.7    0.9   22.3   50.16      1  4.430000e+08     1.0

# %%
ds2['date'] = ds1['Date'].astype(str).str.extract('(\d+)').astype(int) # This is just the month number
ds2['date']
# Out:
# 1        5
# 2        5
# 4        6
# 5        6
# 7        7
#         ..
# 3629     8
# 3631     9
# 3632     9
# 3634    10
# 3636    10
# Name: date, Length: 1298, dtype: int64

# %% [markdown]
# ### Using regex capture groups to clean 'H's' out of data

# %%
print_data = False
show_positive_cases = False
ds2 = ds1.drop(['Station', 'Stratum','Date','StationID','Time'], axis=1)
# ds2
ds2['Depth'] = ds1['Depth'].astype(str).str.extract('([-+]?\d*\.\d+|\d+)').astype(float)
ds2['TP'] = ds1['TP'].astype(str).str.extract('([-+]?\d*\.\d+|\d+)').astype(float)
ds2['Cl'] = ds1['Cl'].astype(str).str.extract('([-+]?\d*\.\d+|\d+)').astype(float)
ds2['DP'] = ds1['DP'].astype(str).str.extract('([-+]?\d*\.\d+|\d+)').astype(float)
ds2['TN'] = ds1['TN'].astype(str).str.extract('([-+]?\d*\.\d+|\d+)').astype(float)
ds2['TempC'] = ds1['TempC'].astype(str).str.extract('([-+]?\d*\.\d+|\d+)').astype(float)
ds2['Chla'] = ds1['Chla'].astype(str).str.extract('([-+]?\d*\.\d+|\d+)').astype(float)
ds2['Secchi'] = ds1['Secchi'].astype(str).str.extract('([-+]?\d*\.\d+|\d+)').astype(float)
ds2['N:P'] = ((ds2['TN']*1e-3)/14.007)/((ds2['TP']*1e-6)/30.974) #for TN in ds2['TN'] for TP in ds2['TP']]
ds2['date'] = ds1['Date'].astype(str).str.extract('(\d+)').astype(int) # This is just the month number
ds2 = ds2.drop(['NP_Cya_bio'], axis=1)
y = np.array(ds2['target'])
X = np.array(ds2.drop(['target'], axis=1))

if show_positive_cases:
    ds1.iloc[t]
if print_data:
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
        print(ds2)
print(ds2['date'])
# Out:
# 1       0
# 2       0
# 4       0
# 5       0
# 7       0
#        ..
# 3629    0
# 3631    0
# 3632    0
# 3634    1
# 3636    1
# Name: date, Length: 1298, dtype: int64

# %% [markdown]
# ### Simple SVM Testing

# %%
# change from normalize to scale 
from sklearn import svm
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import cross_val_score, cross_val_predict

X_normalized = preprocessing.normalize(X) # normalize X for processing
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
print('C=5\n')
for kernel in kernels:
    svm_classifer = svm.SVC(C=5, kernel=kernel)
    y_predicted = cross_val_predict(svm_classifer, X, y, cv=20)
    print(f'KERNEL: {kernel}')
    print(metrics.classification_report(y, y_predicted))
    print(metrics.confusion_matrix(y, y_predicted))
    print('\n')
print('C=50\n')
for kernel in kernels:
    svm_classifer = svm.SVC(C=50, kernel=kernel)
    y_predicted = cross_val_predict(svm_classifer, X, y, cv=5)
    print(f'KERNEL: {kernel}')
    print(metrics.classification_report(y, y_predicted))
    print(metrics.confusion_matrix(y, y_predicted))
    print('\n')
# Out:
# C=5
# /home/tim/.local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 17 members, which is less than n_splits=20.
#   % (min_groups, self.n_splits)), UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-31beb883dde8> in <module>()
#      10 for kernel in kernels:
#      11     svm_classifer = svm.SVC(C=5, kernel=kernel)
# ---> 12     y_predicted = cross_val_predict(svm_classifer, X, y, cv=20)
#      13     print(f'KERNEL: {kernel}')
#      14     print(metrics.classification_report(y, y_predicted))
#
# /home/tim/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     753     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     754         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 755         for train, test in cv.split(X, y, groups))
#     756
#     757     # Concatenate the predictions
#
# /home/tim/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# /home/tim/.local/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /home/tim/.local/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /home/tim/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /home/tim/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /home/tim/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /home/tim/.local/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /home/tim/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#     839         estimator.fit(X_train, **fit_params)
#     840     else:
# --> 841         estimator.fit(X_train, y_train, **fit_params)
#     842     func = getattr(estimator, method)
#     843     predictions = func(X_test)
#
# /home/tim/.local/lib/python3.6/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     197
#     198         seed = rnd.randint(np.iinfo('i').max)
# --> 199         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     200         # see comment on the other call to np.iinfo in this file
#     201
#
# /home/tim/.local/lib/python3.6/site-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     256                 cache_size=self.cache_size, coef0=self.coef0,
#     257                 gamma=self._gamma, epsilon=self.epsilon,
# --> 258                 max_iter=self.max_iter, random_seed=random_seed)
#     259
#     260         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
# change from normalize to scale 
# eval with ROC AUC stuff
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import LeaveOneOut
from sklearn import svm
from sklearn import preprocessing
from sklearn import metrics
from sklearn.metrics import recall_score, make_scorer
from sklearn.model_selection import cross_val_score, cross_val_predict
# Separate test and training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=True)
y_train_pos = np.where(y_train == 1)
y_test_pos= np.where(y_test == 1)
X_normalized = preprocessing.scale(X) # normalize X for processing
y_pos= np.where(y == 1)
# assert len(y_test_pos[0]) >= 5, "Need at least 5 positive samples in training set"

loo = LeaveOneOut() # Specify cross-val technique
X_train_normalized = preprocessing.normalize(X_train) # normalize X for processing
svm_classifer = svm.SVC()
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
scoring = {'AUC': 'roc_auc', 'Recall': make_scorer(recall_score, zero_division=0)} # using two scroing metrics for training and testing 
best_estimators = []
distros = dict(C=np.logspace(-3, 2, 5), gamma=np.logspace(-9, 3, 10), degree=[2,3,4,5], coef0=[-2,-1,0,1,2])

for kernel in kernels:
    print(f'KERNEL: {kernel}')
    svm_classifer = svm.SVC(kernel=kernel, cache_size=1000)
    print('optimizing hyperparams...') # Parrallelizing several model classifcations 
    search = RandomizedSearchCV(svm_classifer, distros, scoring=make_scorer(recall_score, zero_division=0), n_iter=50, verbose=10, cv=loo, n_jobs=4, pre_dispatch='2*n_jobs')
    search = search.fit(X_normalized, y)
    best_estimators.append(search.best_estimator_)
for estimator in best_estimators:
    print(f'hyperparamters: {estimator}')
    print('testing optimized hyperparams...')
    X_test_normalized = preprocessing.normalize(X_test)
    y_predicted = cross_val_predict(estimator, X_normalized, y, cv=loo, verbose=10, n_jobs=4, pre_dispatch='2*n_jobs')
    print(metrics.classification_report(y, y_predicted))
    print(metrics.confusion_matrix(y, y_predicted))
    print('\n')
# Out:
# KERNEL: linear
# optimizing hyperparams...
# Fitting 1298 folds for each of 50 candidates, totalling 64900 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1687s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0286s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0307s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0655s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1302s.) Setting batch_size=32.
# [Parallel(n_jobs=4)]: Done 216 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 520 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 936 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 1352 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 1832 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=4)]: Done 2312 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=4)]: Done 2856 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 3400 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 4008 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=4)]: Done 4616 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=4)]: Done 5288 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=4)]: Done 5960 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=4)]: Done 6696 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=4)]: Done 7432 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=4)]: Done 8232 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=4)]: Done 9032 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=4)]: Done 9896 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=4)]: Done 10760 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=4)]: Done 11688 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=4)]: Done 12616 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=4)]: Batch computation too slow (2.0638s.) Setting batch_size=6.
# [Parallel(n_jobs=4)]: Batch computation too slow (3.8936s.) Setting batch_size=1.
# [Parallel(n_jobs=4)]: Done 13359 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1982s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done 13400 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=4)]: Done 13462 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=4)]: Done 13528 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=4)]: Done 13598 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=4)]: Done 13668 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=4)]: Done 13742 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 13816 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 13894 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 13972 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 14054 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 14136 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 14222 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 14308 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 14398 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done 14488 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done 14582 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 14676 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 14774 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 14872 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 14974 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 15076 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=4)]: Done 15182 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=4)]: Done 15288 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=4)]: Done 15398 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=4)]: Done 15508 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1873s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0817s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Done 15644 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1673s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done 16500 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=4)]: Done 17444 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=4)]: Batch computation too slow (2.2094s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done 18388 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=4)]: Done 18566 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=4)]: Done 18688 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=4)]: Done 18814 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=4)]: Done 18940 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=4)]: Done 19070 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=4)]: Done 19200 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=4)]: Done 19334 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=4)]: Done 19468 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=4)]: Done 19606 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=4)]: Done 19744 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=4)]: Done 19886 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=4)]: Done 20028 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=4)]: Done 20174 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=4)]: Done 20320 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=4)]: Done 20470 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=4)]: Done 20620 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=4)]: Done 20774 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1959s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0912s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1976s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done 21636 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=4)]: Batch computation too slow (2.1310s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done 22382 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=4)]: Done 22540 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=4)]: Done 22702 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=4)]: Done 22864 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=4)]: Done 23030 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=4)]: Done 23196 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=4)]: Done 23366 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1832s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1100s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1903s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done 24300 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=4)]: Done 25692 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1996s.) Setting batch_size=32.
# [Parallel(n_jobs=4)]: Done 27340 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=4)]: Done 30188 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=4)]: Batch computation too slow (2.0765s.) Setting batch_size=6.
# [Parallel(n_jobs=4)]: Batch computation too slow (3.5176s.) Setting batch_size=1.
# [Parallel(n_jobs=4)]: Done 31650 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1998s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done 31818 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=4)]: Done 32000 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=4)]: Done 32186 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=4)]: Done 32372 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=4)]: Done 32562 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=4)]: Done 32752 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=4)]: Done 32946 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=4)]: Done 33140 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=4)]: Done 33338 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=4)]: Done 33536 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=4)]: Done 33738 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1998s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0998s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1983s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done 34872 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=4)]: Done 36520 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1992s.) Setting batch_size=32.
# [Parallel(n_jobs=4)]: Done 39256 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=4)]: Batch computation too slow (2.3127s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Batch computation too slow (3.3462s.) Setting batch_size=1.
# [Parallel(n_jobs=4)]: Done 40749 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1981s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done 40948 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=4)]: Done 41162 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=4)]: Done 41376 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1759s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0552s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0739s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done 41672 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1725s.) Setting batch_size=32.
# [Parallel(n_jobs=4)]: Done 45048 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=4)]: Done 48600 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=4)]: Batch computation too slow (2.2784s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done 52152 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=4)]: Batch computation too slow (3.3710s.) Setting batch_size=1.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1981s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done 52474 tasks      | elapsed:  6.6min
# [Parallel(n_jobs
tasks      | elapsed:   51.3s
# [Parallel(n_jobs=4)]: Done 35576 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=4)]: Done 37144 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=4)]: Done 38712 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=4)]: Done 40344 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 41976 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 43672 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 45368 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 47128 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 48888 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 50712 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 52536 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done 54424 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done 56312 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 58264 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 60216 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 62232 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 64248 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=4)]: Done 64900 out of 64900 | elapsed:  1.6min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0101s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0225s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0351s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    0.1s
# hyperparamters: SVC(C=0.31622776601683794, break_ties=False, cache_size=100, class_weight=None,
#     coef0=1, decision_function_shape='ovr', degree=4, gamma=0.1,
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
# testing optimized hyperparams...
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0708s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done 136 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1420s.) Setting batch_size=32.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 664 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 1016 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 1215 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 1290 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 1298 out of 1298 | elapsed:    2.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0319s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0731s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.1s
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      1281
#          1.0       0.50      0.06      0.11        17
#
#     accuracy                           0.99      1298
#    macro avg       0.74      0.53      0.55      1298
# weighted avg       0.98      0.99      0.98      1298
#
# [[1280    1]
#  [  16    1]]
#
#
# hyperparamters: SVC(C=0.31622776601683794, break_ties=False, cache_size=100, class_weight=None,
#     coef0=1, decision_function_shape='ovr', degree=3, gamma=2.154434690031878,
#     kernel='poly', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
# testing optimized hyperparams...
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1494s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 288 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 480 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=4)]: Done 584 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=4)]: Done 704 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=4)]: Done 824 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=4)]: Done 960 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=4)]: Done 1096 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=4)]: Done 1248 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=4)]: Done 1288 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done 1298 out of 1298 | elapsed:    8.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0131s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0211s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0407s.) Setting batch_size=8.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    0.1s
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98      1281
#          1.0       0.21      0.47      0.29        17
#
#     accuracy                           0.97      1298
#    macro avg       0.60      0.72      0.63      1298
# weighted avg       0.98      0.97      0.98      1298
#
# [[1250   31]
#  [   9    8]]
#
#
# hyperparamters: SVC(C=100.0, break_ties=False, cache_size=100, class_weight=None, coef0=1,
#     decision_function_shape='ovr', degree=3, gamma=0.004641588833612773,
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
# testing optimized hyperparams...
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0858s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done 136 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1759s.) Setting batch_size=32.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 664 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 1016 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 1184 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 1290 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 1298 out of 1298 | elapsed:    2.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0085s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0145s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0274s.) Setting batch_size=8.
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      1281
#          1.0       0.73      0.47      0.57        17
#
#     accuracy                           0.99      1298
#    macro avg       0.86      0.73      0.78      1298
# weighted avg       0.99      0.99      0.99      1298
#
# [[1278    3]
#  [   9    8]]
#
#
# hyperparamters: SVC(C=100.0, break_ties=False, cache_size=100, class_weight=None, coef0=-1,
#     decision_function_shape='ovr', degree=3, gamma=0.004641588833612773,
#     kernel='sigmoid', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
# testing optimized hyperparams...
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.0543s.) Setting batch_size=16.
# [Parallel(n_jobs=4)]: Done 136 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1148s.) Setting batch_size=32.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 664 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 1016 tasks      | elapsed:    1.6s
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      1281
#          1.0       0.33      0.06      0.10        17
#
#     accuracy                           0.99      1298
#    macro avg       0.66      0.53      0.55      1298
# weighted avg       0.98      0.99      0.98      1298
#
# [[1279    2]
#  [  16    1]]
# [Parallel(n_jobs=4)]: Done 1184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 1228 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 1298 out of 1298 | elapsed:    2.0s finished

# %%
for params in final_params:
    print(f'hyperparamters: {params}')
    print('testing optimized hyperparams...')
    X_test_normalized = preprocessing.normalize(X_test)
    svm_classifer = svm.SVC(**params)
    svm_classifer.fit(X_train_normalized, y_train)
#     = cross_val_predict(svm_classifer, X_test_normalized, y_test, cv=len(y_test_pos[0]), verbose=10, n_jobs=4, pre_dispatch='2*n_jobs')
    y_predicted = svm_classifer.predict(X_test)
    print(metrics.classification_report(y_test, y_predicted))
    print(metrics.confusion_matrix(y_test, y_predicted))
    print('\n')
print(final_params)
# Out:
# []

# %% [markdown]
# ### Perform PCA to view data

# %%
ds1['NP_Cya_bio']
# Out:
# 1               0.0
# 2               0.0
# 4               0.0
# 5               0.0
# 7          741000.0
#            ...
# 3629    389000000.0
# 3631    133000000.0
# 3632    443000000.0
# 3634      9460000.0
# 3636      6510000.0
# Name: NP_Cya_bio, Length: 1298, dtype: float64

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing

X_normalized = preprocessing.normalize(X[:, 0:8]) # normalize X for processing
principal_components = PCA(n_components=2)
principal_components.fit(X_normalized)
X_reduced = principal_components.fit_transform(X_normalized)
X_reduced = preprocessing.scale(X_reduced)
fig, ax = plt.subplots(figsize=(10,6))
scatter_plot = ax.scatter(X_reduced[:,0], X_reduced[:,1], c=np.array(ds1['NP_Cya_bio']), cmap=plt.cm.coolwarm,vmax = 4e8)
fig.colorbar(scatter_plot, ax=ax)
ax.set_xlabel('X1')
ax.set_ylabel('X2')
# for ii, xx in enumerate(X_reduced):
#     if y[ii] == 0:
#         ax[0].scatter(xx[0], xx[1], c='r')
#     else:
#         ax[1].scatter(xx[0], xx[1], c='b')
# plt.setp(ax, xlim=(-1,1.6), ylim=(-4,4))
# Out:
# Text(0, 0.5, 'X2')

# %%
ds2
# Out:
#       Depth     TP    DP    Cl    TN  TempC   Chla  Secchi  target        N:P  \
# 1       2.2   36.8  14.8  17.5  0.45   13.7   9.67     1.1     0.0  27.040633
# 2       2.0   50.1  27.4  12.1  0.55   14.5   2.04     0.7     0.0  24.276000
# 4       2.0   59.6  32.6  12.0  0.65   17.7   4.13     0.6     0.0  24.116777
# 5       1.2   77.3  47.9  10.5  0.62   22.5   1.74     0.6     0.0  17.736355
# 7       2.0  107.0  49.9  10.6  0.87   21.4   2.17     0.2     0.0  17.979915
# ...     ...    ...   ...   ...   ...    ...    ...     ...     ...        ...
# 3629    2.2   53.4  16.8   8.0  0.69   25.6  27.50     1.1     0.0  28.573274
# 3631    2.0   83.4  33.9   8.3  0.71   23.7  23.94     1.0     0.0  18.825411
# 3632    2.0   94.2  40.7   8.7  0.90   22.3  50.16     1.0     1.0  21.127289
# 3634    2.8   68.8  42.6   9.6  0.74   13.4  10.22     1.4     0.0  23.784578
# 3636    2.6   79.4  49.7   9.2  0.76    9.2  11.81     1.3     0.0  21.166315
#
#       date
# 1        0
# 2        0
# 4        0
# 5        0
# 7        0
# ...    ...
# 3629     0
# 3631     0
# 3632     0
# 3634     1
# 3636     1
#
# [1298 rows x 11 columns]

# %% [markdown]
# ##
